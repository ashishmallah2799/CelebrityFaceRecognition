# %% [markdown]
# # DATA CLEANING

# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test_images/LionelMessi.jpg')
img.shape
# Out:
# (1200, 1200, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (1200, 1200)

# %%
gray
# Out:
# array([[224, 224, 224, ..., 220, 220, 220],
#        [224, 224, 224, ..., 220, 220, 220],
#        [224, 224, 224, ..., 220, 220, 220],
#        ...,
#        [226, 226, 226, ..., 219, 219, 219],
#        [226, 226, 226, ..., 219, 219, 219],
#        [225, 225, 225, ..., 219, 219, 219]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[444, 120, 331, 331]], dtype=int32)

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (444, 120, 331, 331)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images/Deepika_Padukone.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/Deepika_Padukone.jpg')
plt.imshow(cropped_image)

# %%
org_image_obstructed = cv2.imread('./test_images/LeoMessi.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images/LeoMessi.jpg')
cropped_image_no_2_eyes

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/Salman_Khan',
#  './dataset/Shraddha_Kapoor',
#  './dataset/Sonakshi_Sinha',
#  './dataset/Varun_Dhawan',
#  './dataset/Yami_Gautam']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name 
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Salman_Khan
# Generating cropped images in folder:  ./dataset/cropped/Salman_Khan
# Shraddha_Kapoor
# Generating cropped images in folder:  ./dataset/cropped/Shraddha_Kapoor
# Sonakshi_Sinha
# Generating cropped images in folder:  ./dataset/cropped/Sonakshi_Sinha
# Varun_Dhawan
# Generating cropped images in folder:  ./dataset/cropped/Varun_Dhawan
# Yami_Gautam
# Generating cropped images in folder:  ./dataset/cropped/Yami_Gautam

# %% [markdown]
# # Feature Engineering

# %%
import numpy as np
import pywt
import cv2

def w2d(img, mode='haar', level=1):
    imArray = img
    
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    imArray = np.float32(imArray)
    imArray /= 255;
    coeffs=pywt.wavedec2(imArray, mode, level=level)
    
    coeffs_H=list(coeffs)
    coeffs_H[0] *= 0;
    
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H = np.uint8(imArray_H)
    
    return imArray_H

# %%
im_har = w2d(cropped_image,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
celebrity_file_names_dict
# Out:
# {'Salman_Khan': ['./dataset/cropped/Salman_Khan/Salman_Khan1.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan2.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan3.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan4.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan5.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan6.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan7.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan8.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan9.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan10.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan11.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan12.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan13.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan14.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan15.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan16.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan17.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan18.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan19.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan20.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan21.png',
#   './dataset/cropped/Salman_Khan/Salman_Khan22.png'],
#  'Shraddha_Kapoor': ['./dataset/cropped/Shraddha_Kapoor/Shraddha_Kapoor1.png',
#   './dataset/cropped/Shraddha_Kapoor/Shraddha_Kapoor2.png',
#   './dataset/cropped/Shraddha_Kapoor/Shraddha_Kapoor3.png',
#   './dataset/cropped/Shraddha_Kapoor/Shraddha_Kapoor4.png',
#   './dataset/cropped/Shraddha_Kapoor/Shraddha_Kapoor5.png',
#   './dataset/cropped/Shraddha_Kapoor/Shraddha_Kapoor6.png',
#   './dataset/cropped/Shraddha_Kapoor/Shraddha_Kapoor7.png',
#   './dataset/cropped/Shraddha_Kapoor/Shraddha_Kapoor8.png',
#   './dataset/cropped/Shraddha_Kapoor/Shraddha_Kapoor9.png',
#   './dataset/cropped/Shraddha_Kapoor/Shraddha_Kapoor10.png',
#   './dataset/cropped/Shraddha_Kapoor/Shraddha_Kapoor11.png',
#   './dataset/cropped/Shraddha_Kapoor/Shraddha_Kapoor12.png',
#   './dataset/cropped/Shraddha_Kapoor/Shraddha_Kapoor13.png',
#   './dataset/cropped/Shraddha_Kapoor/Shraddha_Kapoor14.png',
#   './dataset/cropped/Shraddha_Kapoor/Shraddha_Kapoor15.png',
#   './dataset/cropped/Shraddha_Kapoor/Shraddha_Kapoor16.png',
#   './dataset/cropped/Shraddha_Kapoor/Shraddha_Kapoor17.png'],
#  'Sonakshi_Sinha': ['./dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha1.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha2.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha3.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha4.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha5.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha6.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha7.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha8.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha9.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha10.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha11.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha12.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha13.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha14.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha15.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha16.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha17.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha18.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha19.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha20.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha21.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha22.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha23.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha24.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha25.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha26.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha27.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha28.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha29.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha30.png',
#   './dataset/cropped/Sonakshi_Sinha/Sonakshi_Sinha31.png'],
#  'Varun_Dhawan': ['./dataset/cropped/Varun_Dhawan/Varun_Dhawan1.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan2.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan3.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan4.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan5.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan6.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan7.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan8.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan9.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan10.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan11.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan12.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan13.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan14.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan15.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan16.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan17.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan18.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan19.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan20.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan21.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan22.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan23.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan24.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan25.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan26.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan27.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan28.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan29.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan30.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan31.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan32.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan33.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan34.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan35.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan36.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan37.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan38.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan39.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan40.png',
#   './dataset/cropped/Varun_Dhawan/Varun_Dhawan41.png'],
#  'Yami_Gautam': ['./dataset/cropped/Yami_Gautam/Yami_Gautam1.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam2.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam3.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam4.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam5.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam6.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam7.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam8.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam9.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam10.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam11.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam12.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam13.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam14.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam15.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam16.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam17.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam18.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam19.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam20.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam21.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam22.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam23.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam24.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam25.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam26.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam27.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam28.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam29.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam30.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam31.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam32.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam33.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam34.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam35.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam36.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam37.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam38.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam39.png',
#   './dataset/cropped/Yami_Gautam/Yami_Gautam40.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'Salman_Khan': 0,
#  'Shraddha_Kapoor': 1,
#  'Sonakshi_Sinha': 2,
#  'Varun_Dhawan': 3,
#  'Yami_Gautam': 4}

# %%
X = []
y = []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        if img is None:
            continue
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img, 'db1', 5)
        scalled_img_har = cv2.resize(img_har , (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
X[0]
# Out:
# array([[ 14],
#        [ 58],
#        [109],
#        ...,
#        [246],
#        [246],
#        [246]], dtype=uint8)

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (151, 4096)

# %%
X[0]
# Out:
# array([ 14.,  58., 109., ..., 246., 246., 246.])

# %% [markdown]
# # Training a model

# %% [markdown]
# #we will use svm with rbf kernel tuned with heuristic finetuning

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'linear', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.7105263157894737

# %%
len(X_test)
# Out:
# 38

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.75      0.60         4
#            1       1.00      0.50      0.67         6
#            2       0.75      0.67      0.71         9
#            3       0.90      0.75      0.82        12
#            4       0.55      0.86      0.67         7
#
#     accuracy                           0.71        38
#    macro avg       0.74      0.70      0.69        38
# weighted avg       0.77      0.71      0.72        38

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn .linear_model import LogisticRegression
from sklearn.pipeline import  make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
          'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression': {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params' : {
            'logisticregression__C': [1,5,10]
        }
    } 
}

# %%
scores = []
best_estimators = {}
import pandas as pd 
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf = GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.664032
# 1        random_forest    0.442688
# 2  logistic_regression    0.592490
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 5}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.7105263157894737

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.4473684210526316

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.6578947368421053

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[3, 0, 0, 0, 1],
#        [0, 3, 2, 0, 1],
#        [1, 0, 6, 0, 2],
#        [2, 0, 0, 9, 1],
#        [0, 0, 0, 1, 6]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'Salman_Khan': 0,
#  'Shraddha_Kapoor': 1,
#  'Sonakshi_Sinha': 2,
#  'Varun_Dhawan': 3,
#  'Yami_Gautam': 4}

# %%
# !pip install joblib
import joblib

joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\ashis\anaconda3\lib\site-packages (1.0.1)
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
